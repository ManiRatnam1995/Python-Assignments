# %% [markdown]
# 1. Create an assert statement that throws an AssertionError if the variable spam is a negative
# integer.

# %%
spam = int(input())
assert spam > 0 ,"Assertion error"
# Out:
#  -5
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 spam = int(input())
# ----> 2 assert spam > 0 ,"Assertion error"
#
# AssertionError: Assertion error

# %%
assert spam < 0 ,"Assertion error"

# %% [markdown]
# 2. Write an assert statement that triggers an AssertionError if the variables eggs and bacon contain
# strings that are the same as each other, even if their cases are different (that is, &#39;hello&#39; and &#39;hello&#39; are
# considered the same, and &#39;goodbye&#39; and &#39;GOODbye&#39; are also considered the same).

# %%
def strings():
    a=input("str1:")
    b=input("str2:")
    a1=[]
    b1=[]
    c=""
    d=""
    for char in a:
        if char.isupper():
            char.lower()
            a1.append(char)
        else:
            a1.append(char)
    c.join(a1)
            
    for var in b:
        if var.isupper():
            var.lower()
            b1.append(var)
        else:
            b1.append(var)
    d.join(b1)
    assert c != d ,"Assertion error"

# %%
strings()
# Out:
# str1: Hello
# str2: hello
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 strings()
#
# Cell In[3], line 23, in strings()
#      21         b1.append(var)
#      22 d.join(b1)
# ---> 23 assert c != d ,"Assertion error"
#
# AssertionError: Assertion error

# %% [markdown]
# 3. Create an assert statement that throws an AssertionError every time.

# %%
a=5
b=6
assert a==b,"errorified"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 3
#       1 a=5
#       2 b=6
# ----> 3 assert a==b,"errorified"
#
# AssertionError: errorified

# %% [markdown]
# 4. What are the two lines that must be present in your software in order to call logging.debug()?

# %%
#import logging
#logging.basicconfig(level=logging.DEBUG)

# %% [markdown]
# 5. What are the two lines that your program must have in order to have logging.debug() send a
# logging message to a file named programLog.txt?

# %%
#import logging
#logging.basicconfig(filename=programlog.txt,level=logging.DEBUG)

# %% [markdown]
# 6. What are the five levels of logging?

# %% [markdown]
# DEBUG,INFO,WARNING,ERROR,CRITICAL

# %% [markdown]
# 7. What line of code would you add to your software to disable all logging messages?

# %%
#logging.disable(logging.CRITICAL)

# %% [markdown]
# 8.Why is using logging messages better than using print() to display the same message?

# %% [markdown]
# Assignation of levels is what print statement does not have

# %% [markdown]
# 9. What are the differences between the Step Over, Step In, and Step Out buttons in the debugger?

# %% [markdown]
# Step in usually tries to go inside function and stops at the first line,Step over generally goes through the entire function stops before next scope,step out lets every thing run and the function call back returns to the caller

# %% [markdown]
# 10.After you click Continue, when will the debugger stop ?

# %% [markdown]
# until it reaches a breakpoint or program finishes execution

# %% [markdown]
# 11. What is the concept of a breakpoint?

# %% [markdown]
# marker set in a code that tells a debugger"Kindly stop the program he
