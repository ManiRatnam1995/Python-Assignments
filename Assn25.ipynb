# %% [markdown]
# 1) . What is the difference between enclosing a list comprehension in square brackets and
# parentheses?

# %%
#Enclosing a list function in square bracket makes it a list and parantheses makes it a tuple

# %% [markdown]
# 2) What is the relationship between generators and iterators?

# %%
#Generators are formed when yield is used to yield the values required whereqas iterators are those who perform iteration on iterables

# %% [markdown]
# 3) What are the signs that a function is a generator function?

# %%
#1.yield is used inside the function inorder to yield outputs
#2.An object formed due to function is there and its path is displayed when the function is called

# %% [markdown]
# 4) What is the purpose of a yield statement?

# %%
#yield statement in a function is used to form a generator function

# %% [markdown]
# 5) What is the relationship between map calls and list comprehensions? Make a comparison and
# contrast between the two.

# %%
#comparison and contrast
#1.map calls recognise the elements provided to it and they are generally provided in list
#2.map callls are preferred over loops in many cases vwhich makes the code short and simple
#3 map is ofted used with lambda function where as list is the values enwrapped inside square brackets
#4.map recognises elements po
