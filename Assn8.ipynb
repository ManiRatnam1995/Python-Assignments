# %% [markdown]
# 1. Is the Python Standard Library included with PyInputPlus?

# %% [markdown]
# Yes

# %% [markdown]
# 2. Why is PyInputPlus commonly imported with import pyinputplus as pypi?

# %% [markdown]
# It helps you find and installed softwares developed by python

# %% [markdown]
# 3. How do you distinguish between inputInt() and inputFloat()?

# %% [markdown]
# inputint() lets you enter an integer with constraints ,inputfloat() lets you enter a floating point number with constraints

# %% [markdown]
# 4. Using PyInputPlus, how do you ensure that the user enters a whole number between 0 and 99?

# %% [markdown]
# We ensure it by creating constraints where we have to enter minimum and maximum value

# %% [markdown]
# 5. What is transferred to the keyword arguments allowRegexes and blockRegexes?

# %% [markdown]
# Regexes can also be  transferred to keyword arguments called allowRegexes and you cannot transfer regexes in keyword arguent called block regexes

# %% [markdown]
# 6. If a blank input is entered three times, what does inputStr(limit=3) do?

# %% [markdown]
# User gets only three times to enter valid inputs

# %% [markdown]
# 7. If blank input is entered three times, what does inputStr(limit=3, default=&#39;hello&#39;) do?

# %% [markdown]
# "Hello" will be printed three times
