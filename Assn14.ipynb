# %% [markdown]
# 1. What does RGBA stand for?

# %% [markdown]
# Red,Green,Blue and alpha

# %% [markdown]
# 2. From the Pillow module, how do you get the RGBA value of any images?

# %%
#import pillow
#r,g,b,a = img.getpixel((50,50))

# %% [markdown]
# 3. What is a box tuple, and how does it work?

# %% [markdown]
# a box tuple is related to boundaries of a rectangular portion and all four vertices.
# as you move horizontally n, x increases,as you move down y increases.

# %% [markdown]
# 4. Use your image and load in notebook then, How can you find out the width and height of an
# Image object?

# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in c:\users\hp\anaconda3\lib\site-packages (10.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image

# %%
img=Image.open("OIP.webp")

# %%
width,height=img.size

# %% [markdown]
# 5. What method would you call to get Image object for a 100×100 image, excluding the lower-left
# quarter of it?

# %% [markdown]
# crop[() method

# %% [markdown]
# 6. After making changes to an Image object, how could you save it as an image file?

# %% [markdown]
# img.save()

# %% [markdown]
# 7. What module contains Pillow’s shape-drawing code?

# %% [markdown]
# Image Draw
