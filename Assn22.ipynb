# %% [markdown]
# 1. What is the result of the code, and explain?

# %%
X ="ineuron"
def func():
    print(x)

# %%
func()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 func()
#
# Cell In[1], line 3, in func()
#       2 def func():
# ----> 3     print(x)
#
# NameError: name 'x' is not defined

# %%
#X should have a value inside the function.X is a variable here to be called

# %% [markdown]
# 2. What is the result of the code, and explain?

# %%
x="ineuron"
def func():
    x="NI!"

# %%
func()

# %%
x
# Out:
# 'ineuron'

# %% [markdown]
# #Here we have not added the print,yield or return method to showcase the value of variable X.Therefore fun() will not showcase anything where as the variable outside of function will showcase its value

# %% [markdown]
# 3. What does this code print, and why?

# %%
x="ineuron"

def func():
    x="Ni"
    print(x)

# %%
func()
# Out:
# Ni

# %%
#This function has been asked to print a certain value therefore this function prints it.

# %%
print(x)
# Out:
# ineuron

# %%
#value of variable x away from the function is this therefore value of variable x is printed this way

# %% [markdown]
# 4. What output does this code produce? Why?

# %%
x="ineuron"

# %%
def func():
    global x
    x="NI"

# %%
func()

# %%
#No print() function added inside the given function

# %%
print(x)
# Out:
# NI

# %%
#X variable given away from the function

# %% [markdown]
# #5. What about this code—what’s the output, and why?

# %%
x="ineuron"
def func():
    X ="NI"

def nested():
    print(x)

func()
X
# Out:
# 'ineuron'

# %%
#Print function isnt gi8ven where value is given and value is not given where print function is given

# %% [markdown]
# 6. How about this code: what is its output in Python 3, and explain?

# %%
def func():
    x="NI"

def nested():
    nonlocal X 

X = "Spam"

nested()
