# %% [markdown]
# 1. What is the relationship between def statements and lambda expressions ?

# %%
#1.Def is something that creates a function
#2. Lambda is already a function
#3 lambda function is a short path to obtain results.
#4 Def is also a function built to create a function.

# %% [markdown]
# 2. What is the benefit of lambda?

# %%
#LAMBDA FUNCTION IS A SHORT PATH TO OBTAIN RESULTS

# %% [markdown]
# 3. Compare and contrast map, filter, and reduce.

# %%
#MAP FUNCTION IS USED TO RECOGNIZE CERTAIN ELEMENTS
#FILTER IS USED TO TAKE OUT SPECIFIC ELEMENTS
#reduce is used after recognition of certain elements to reduce boundaries

# %% [markdown]
# 4. What are function annotations, and how are they used?

# %%
#parameters and return value are usually known as function annotation.They are used to showcase the type of values inside function and the type of return value to be obtained

# %% [markdown]
# 5. What are recursive functions, and how are they used?

# %%
#reccursive function operates in recursion. It starts from the bottom variable and goes till the peak..

# %% [markdown]
# 6. What are some general design guidelines for coding functions?

# %%
#1.def function is used 
#2.if you have to make it a generator tham yield function is to be used
#3.return or print statement is generally used for output
#4.Proper indentation is necessary

# %% [markdown]
# 7. Name three or more ways that functions can communicate results to a caller.

# %%
#calling a function
#calling a function and displaying inputs to be given for results
#if you are using function inside classes than yo0u to make an obj
