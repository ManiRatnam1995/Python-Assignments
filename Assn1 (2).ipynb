# %% [markdown]
# # Ans1<a href="#Ans1" class="anchor-link">¶</a>
#
# \* - / + are expression and "hello" ,6 ,-87.8 are values
#
# # Ans2<a href="#Ans2" class="anchor-link">¶</a>
#
# String is mutable and the entity which it mutates on can be called
# variables. String in enquoted where as varuiable need not be enquoted.
#
# # Ans3<a href="#Ans3" class="anchor-link">¶</a>
#
# Numeric ,Boolean and Binary are three different data types
#
# # Ans4<a href="#Ans4" class="anchor-link">¶</a>
#
# An expression is made up of a mathematical operator. All expression help
# in mathematicatical operation within a function and outside the function
#
# # Ans5<a href="#Ans5" class="anchor-link">¶</a>
#
# spam =10 Here statements tells that variable "spam" contains 10 units of
# number which is 1 and expression "=" tells that variable "spam" is
# equivalent to number 10 or vice versa
#
# # Ans6<a href="#Ans6" class="anchor-link">¶</a>
#
# Here bacon =22 bacon+1 =23 bacon still contains 22 as new variable isnt
# assigned to bacon+1
#
# # Ans7<a href="#Ans7" class="anchor-link">¶</a>
#
# In \[6\]:
#
#     "spam" + "spamspam"
#
# Out\[6\]:
#
#     'spamspamspam'
#
# In \[7\]:
#
#     "spam" *3
#
# Out\[7\]:
#
#     'spamspamspam'
#
# # Ans8<a href="#Ans8" class="anchor-link">¶</a>
#
# Eggs is a valid variable name because it contains only alphabets where
# as 100 is an integer & an integer cannot be a variable .
#
# # Ans9<a href="#Ans9" class="anchor-link">¶</a>
#
# int() float() str()
#
# # Ans10<a href="#Ans10" class="anchor-link">¶</a>
#
# 'I have eaten ' + 99 + ' burritos.'
#
# This expression causes an error because a string joins only other
# string.This can be fixed in way given below
#
# In \[13\]:
#
#     'I have eaten'   +    '99'  +'burritos'
#
# Out\[13\]:
#
#     'I have eaten99burritos'
#
# In \[ \]:
