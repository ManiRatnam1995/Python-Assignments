# %% [markdown]
# 1. Why are functions advantageous to have in your programs?

# %% [markdown]
# Functions are advantageous to have because of simplicity ,high latency as well as reusability of the code .

# %% [markdown]
# 2. When does the code in a function run: when it&#39;s specified or when it&#39;s called?

# %% [markdown]
# WHenever a function is called through the call method ,code inside it runs.

# %% [markdown]
# 3. What statement creates a function?

# %% [markdown]
# def followed by the name and parantheses one wants to give for a function creates a function .example def mani_beauty()

# %% [markdown]
# 4. What is the difference between a function and a function call?

# %% [markdown]
# Function is a method of creating a procedure with the code written inside it having the speciality of high latency and reusability where as function call is a method of using the same procedure that you have created to solve your problems

# %% [markdown]
# 5. How many global scopes are there in a Python program? How many local scopes?

# %% [markdown]
# There can be as many global variable as one wants in a program,same goes with local variables

# %% [markdown]
# 6. What happens to variables in a local scope when the function call returns?

# %% [markdown]
# local variables get executed in such cases

# %% [markdown]
# 7. What is the concept of a return value? Is it possible to have a return value in an expression?

# %% [markdown]
# "Return" is used inside a function .It is somewhere similar to ]print statement that gives the output.it is completely possible to have a return value in an expression if the expression is inside a function.

# %% [markdown]
# 8. If a function does not have a return statement, what is the return value of a call to that function?

# %% [markdown]
# if the function doesnt have return statement ,it can have print() statement for the desired output

# %% [markdown]
# 9. How do you make a function variable refer to the global variable?

# %% [markdown]
# function variable can be referrred to global variable or vice versa .Here are examples :-

# %%
def add(a,b):
    return(a+b)

s=add(4,5)
print(s)
# Out:
# 9

# %%
#Vice Versa
isotope=31

def iso():
    return isotope

# %%
iso()
# Out:
# 31

# %% [markdown]
# 10. What is the data type of None?

# %% [markdown]
# Nonetype data are generally datas that have absence of value or nullity

# %% [markdown]
# 11. What does the sentence import areallyourpetsnamederic do?

# %%
import areallyourpetsnamederic
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import areallyourpetsnamederic
#
# ModuleNotFoundError: No module named 'areallyourpetsnamederic'

# %% [markdown]
# "No such module exists"

# %% [markdown]
# 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

# %% [markdown]
# There might be two scenarios here
# 1. from spam import bacon
# or
# 2.spam.bacon()

# %% [markdown]
# 13. What can you do to save a programme from crashing if it encounters an error?

# %% [markdown]
# Try,except and finally blocks are there to stop crashing if program encounters an error

# %% [markdown]
# 14. What is the purpose of the try clause? What is the purpose of the except clause?

# %% [markdown]
# Try clause tries the argument and if the argument is not satisfying the condition then it creates an error ,except clause handles the same error and stops the program from crashing
