# %% [markdown]
# #Ans1

# %% [raw]
# * - / + are expression and "hello" ,6 ,-87.8 are values

# %% [markdown]
# #Ans2

# %% [raw]
# String is mutable and the entity which it mutates on can be called variables.
# String in enquoted where as varuiable need not be enquoted.

# %% [markdown]
# #Ans3

# %% [raw]
# Numeric ,Boolean and Binary are three different data types

# %% [markdown]
# #Ans4

# %% [raw]
# An expression is made up of a mathematical operator. All expression help in mathematicatical operation within a function and outside the function

# %% [markdown]
# #Ans5

# %% [raw]
# spam =10
# Here statements tells that variable "spam"  contains 10 units of number which is 1 and expression "=" tells that variable "spam" is equivalent to number 10 or vice versa

# %% [markdown]
# #Ans6

# %% [raw]
# Here
# bacon =22
#  bacon+1 =23
#
# bacon still contains 22 as new variable isnt assigned to bacon+1

# %% [markdown]
# #Ans7

# %%
"spam" + "spamspam"
# Out:
# 'spamspamspam'

# %%
"spam" *3
# Out:
# 'spamspamspam'

# %% [markdown]
# #Ans8

# %% [raw]
# Eggs is a valid variable name because it contains only alphabets where as 100 is an integer & an integer cannot be a variable .

# %% [markdown]
# #Ans9

# %% [raw]
# int() float() str()

# %% [markdown]
# #Ans10

# %% [markdown]
# &#39;I have eaten &#39; + 99 + &#39; burritos.&#39;

# %% [raw]
# This expression causes an error because a string joins only other string.This can be fixed in way given below

# %%
'I have eaten'   +    '99'  +'burritos'
# Out:
# 'I have eaten99burritos'
