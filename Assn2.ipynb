# %% [markdown]
# 1.What are the two values of the Boolean data type? How do you write them?

# %% [markdown]
# True (1) & False(0)

# %% [markdown]
# 2. What are the three different types of Boolean operators?

# %% [markdown]
# AND , OR & NOT

# %% [markdown]
# 3. Make a list of each Boolean operator&#39;s truth tables (i.e. every possible combination of Boolean
# values for the operator and what it evaluate ).

# %%
a=5
b=10

if a < 10 and b < 15 :
    print("Its ok")
# Out:
# Its ok

# %%
if a == 5 or b ==16 :
    print("ham")
# Out:
# ham

# %%
print(not a)
# Out:
# False

# %% [markdown]
# 4. What are the values of the following expressions?
# (5 &gt; 4) and (3 == 5)
# not (5 &gt; 4)
# (5 &gt; 4) or (3 == 5)
# not ((5 &gt; 4) or (3 == 5))
# (True and True) and (True == False)
# (not False) or (not True)

# %%
(5>4) and (3==5)
# Out:
# False

# %%
not(5>4)
# Out:
# False

# %%
(5>4) and (3==5)
# Out:
# False

# %%
not((5>4) or (3==5))
# Out:
# False

# %%
(True and True) and (True==False)
# Out:
# False

# %%
not(False) or not(True)
# Out:
# True

# %% [markdown]
# 5. What are the six comparison operators?

# %% [markdown]
# == ,!= , <,> ,>=,<=

# %% [markdown]
# 6. How do you tell the difference between the equal to and assignment operators?Describe a
# condition and when you would use one.

# %% [markdown]
# "=" comes in the procedure of assignment .illustration :-

# %%
a=10
print(a)
# Out:
# 10

# %% [markdown]
# Here 10 is assigned to variable a and "=" comes in procedure of assigning the variable

# %% [markdown]
# 7. Identify the three blocks in this code:
# spam = 0
# if spam == 10:
# print(&#39;eggs&#39;)
# if spam &gt; 5:
# print(&#39;bacon&#39;)
# else:
# print(&#39;ham&#39;)
# print(&#39;spam&#39;)
# print(&#39;spam&#39;)

# %%
spam=0
if spam > 5:
    print("bacon")
if spam ==10:
    print("eggs")
else:
    print("ham")
    print("spam")
    print("spam")
# Out:
# ham
# spam
# spam

# %% [markdown]
# 8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints
# Greetings! if anything else is stored in spam.

# %%
spam=int(input("Enter the number:"))
if spam ==1:
    print("Hello")
elif spam == 2:
    print("Howdy")
else:
    print("Greetings")

# %% [markdown]
# 9.If your programme is stuck in an endless loop, what keys you’ll press?

# %% [markdown]
# BREAK

# %% [markdown]
# 10. How can you tell the difference between break and continue?

# %% [markdown]
# BREAK breaks the process which might be loop in a scenario whereas CONTINUE helps in continuing the process which might be completing or continuing the loop in a scenario

# %% [markdown]
# 11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?

# %% [markdown]
# When we execute the forloop in all three scenarios ,we get the same result, range(10) means bottom end of a node starting from zero and ending before upper node 10,i.e 9

# %% [markdown]
# range(0,10) means the same where jump of rank 1 is automated in both the cases

# %% [markdown]
# range(0,10,1) means the same thing but "1" here means the jump of rank 1. If 2 is specified then there is going to be the jump of rank 2

# %% [markdown]
# 12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent
# program that prints the numbers 1 to 10 using a while loop.

# %%
for char in range(1,11):
    print(char)

var=1

while var < 11:
    print(var)
    var=var+1

# %% [markdown]
# 13. If you had a function named bacon() inside a module named spam, how would you call it after
# importing spam?

# %% [markdown]
# from spam import bacon
