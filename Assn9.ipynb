# %% [markdown]
# 1. To what does a relative path refer?

# %% [markdown]
# It refers to the path which is related.Its shorter and more reliable than absolute path

# %% [markdown]
# 2. What does an absolute path start with your operating system?

# %% [markdown]
# Absolute part starts tracking down the location of path where a targeted file or object is stored

# %% [markdown]
# 3. What do the functions os.getcwd() and os.chdir() do?

# %% [markdown]
# os.getcwd() gets the current working directory for you whereas os.chdir() changes the working directory for you.

# %% [markdown]
# 4. What are the . and .. folders?

# %% [markdown]
# . refers to the current folder you are in and .. refers to the parent folder

# %% [markdown]
# 5. In C:\bacon\eggs\spam.txt, which part is the dir name, and which part is the base name?

# %% [markdown]
# directory name is except the file name and remaining is the base name

# %% [markdown]
# 6. What are the three “mode” arguments that can be passed to the open() function?

# %% [markdown]
# read ,write and append mode

# %% [markdown]
# 7. What happens if an existing file is opened in write mode?

# %% [markdown]
# THen you can write in the existing file

# %% [markdown]
# 8. How do you tell the difference between read() and readlines()?

# %% [markdown]
# Read mode helps you read the file and readlines mode helps you specify some lines as a list and every word as a string inside it
