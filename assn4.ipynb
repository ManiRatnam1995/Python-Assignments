# %% [markdown]
# 1. What exactly is []?

# %% [markdown]
# This is an empty list

# %% [markdown]
# 2. In a list of values stored in a variable called spam, how would you assign the value &#39;hello&#39; as the
# third value? (Assume [2, 4, 6, 8, 10] are in spam.)

# %%
spam=[2,4,6,8,10]
spam[3]='hello'

# %%
spam[3]
# Out:
# 'hello'

# %% [markdown]
# Mutability of list help us reassign the value

# %% [markdown]
# Let&#39;s pretend the spam includes the list [&#39;a&#39;, &#39;b&#39;, &#39;c&#39;, &#39;d&#39;] for the next three queries.

# %% [markdown]
# 3. What is the value of spam[int(int(&#39;3&#39; * 2) / 11)]?

# %%
spam=['a','b','c','d']

# %%
spam[int(int('3'*2)/11)]
# Out:
# 'd'

# %% [markdown]
# 4. What is the value of spam[-1]?

# %%
spam[-1]
# Out:
# 'd'

# %% [markdown]
# 5. What is the value of spam[:2]?

# %%
spam[:2]
# Out:
# ['a', 'b']

# %% [markdown]
# Let&#39;s pretend bacon has the list [3.14, &#39;cat,&#39; 11, &#39;cat,&#39; True] for the next three questions.

# %% [markdown]
# 6. What is the value of bacon.index(&#39;cat&#39;)?

# %%
bacon=[3.14,'cat',11,'cat',True]

# %%
bacon.index('cat')
# Out:
# 1

# %% [markdown]
# 7. How does bacon.append(99) change the look of the list value in bacon?

# %%
bacon.append(99)

# %%
bacon
# Out:
# [3.14, 'cat', 11, 'cat', True, 99]

# %% [markdown]
# 8. How does bacon.remove(&#39;cat&#39;) change the look of the list in bacon?

# %%
bacon.remove('cat')

# %%
bacon
# Out:
# [3.14, 11, 'cat', True, 99]

# %% [markdown]
# 9. What are the list concatenation and list replication operators?

# %% [markdown]
# list concatenation ooperators generally converts multiple lists into a single one thereby having all the elements of those lists into a single list
# list replication operators multiply list and converts a single list into multiple lists with same elements inside.

# %% [markdown]
# 10. What is difference between the list methods append() and insert()?

# %% [markdown]
# List append method appends the element after the last index where as List insert method inserts elements into desirable index.

# %% [markdown]
# 11. What are the two methods for removing items from a list?

# %% [markdown]
# list.append and list.pop are the two methods for removing items from a list

# %% [markdown]
# 12. Describe how list values and string values are identical.

# %%
spam="123"

# %%
print(spam[1])
type(spam[1])
# Out:
# 2
# str

# %%
bacon=["1","2","3"]

# %%
print(bacon[1])
type(bacon[1])
# Out:
# 2
# str

# %% [markdown]
# 13. What&#39;s the difference between tuples and lists?

# %% [markdown]
# Difference of parenthesis exists between tuple and lists are mutable entities whereas tuples are immutable entities and list cannot end with a comma whereas tuples can.

# %% [markdown]
# 14. How do you type a tuple value that only contains the integer 42?

# %%
t=(1,2,42)
for char in t:
    if char == 42:
        print(char)
# Out:
# 42

# %% [markdown]
# 15. How do you get a list value&#39;s tuple form? How do you get a tuple value&#39;s list form?

# %%
spam=[1,2,42]
spam=tuple(spam)
spam
# Out:
# (1, 2, 42)

# %%
bacon=list(spam)
bacon
# Out:
# [1, 2, 42]

# %% [markdown]
# 16. Variables that &quot;contain&quot; list values are not necessarily lists themselves. Instead, what do they
# contain?

# %% [markdown]
# variables contains varying elements.

# %% [markdown]
# 17. How do you distinguish between copy.copy() and copy.deepcopy()?

# %%
copy.copy() copies elements as it is whereas copy.deepcopy() recursively cop

# %%
l=[1,2,3]

# %%
copy.copy(l)
# Out:
# [1, 2, 3]

# %%
copy.deepcopy(l)
# Out:
# [1, 2, 3]
