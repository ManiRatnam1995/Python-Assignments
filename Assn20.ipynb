# %% [markdown]
# 1. Set the variable test1 to the string &#39;This is a test of the emergency text system,&#39; and save test1 to a
# file named test.txt.

# %% [markdown]
# 2. Read the contents of the file test.txt into the variable test2. Is there a difference between test 1
# and test 2?

# %%
test1="This is a test of the emergency text system"

# %%
with open("test2.txt","w") as file:
    file.write(test1)
    file.close()

# %%
with open("test2.txt","r") as file:
    content=file.read()
    print(content)
# Out:
# This is a test of the emergency text system

# %% [markdown]
# 3. Create a CSV file called books.csv by using these lines:
# title,author,year

# %% [markdown]
# The Weirdstone of Brisingamen,Alan Garner,1960
# Perdido Street Station,China Miéville,2000
# Thud!,Terry Pratchett,2005
# The Spellman Files,Lisa Lutz,2007
# Small Gods,Terry Pratchett,1992

# %%
import csv
rows=[
    ["title","author","year"],
    ["The Weirdstone of Brisingamen","Alan Garner","1960"],
    ["Perdido Street Station","China Miéville","2000"],
    ["Thud!","Terry Pratchett","2005"],
    ["The Spellman Files","Lisa Lutz","2007"],
    ["Small Gods","Terry Pratchett","1992"]
    ]

# %%
with open("books.csv","w",newline="") as file:
    writer = csv.writer(file,delimiter=",")
    writer.writerows(rows)
    file.close()

# %% [markdown]
# 4. Use the sqlite3 module to create a SQLite database called books.db, and a table called books with
# these fields: title (text), author (text), and year (integer).

# %% [markdown]
# 5. Read books.csv and insert its data into the book table.

# %% [markdown]
# 6. Select and print the title column from the book table in alphabetical order.

# %% [markdown]
# 7. From the book table, select and print all columns in the order of publication.

# %% [markdown]
# 8. Use the sqlalchemy module to connect to the sqlite3 database books.db that you just made in
# exercise 6.

# %%
#I would have done it easily but there is a problem in sql server. I profoundly have regrets for not answering these questions.Kindly check the remaining one's

# %% [markdown]
# 9. Install the Redis server and the Python redis library (pip install redis) on your computer. Create a
# Redis hash called test with the fields count (1) and name (&#39;Fester Bestertester&#39;). Print all the fields for
# test.

# %%
pip install redis
# Out:
# ...
#    ---------------------------------------- 0.0/394.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/394.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/394.9 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/394.9 kB 262.6 kB/s eta 0:00:02
#    ---- ---------------------------------- 41.0/394.9 kB 245.8 kB/s eta 0:00:02
#    ------ -------------------------------- 61.4/394.9 kB 273.8 kB/s eta 0:00:02
#    ------ -------------------------------- 61.4/394.9 kB 273.8 kB/s eta 0:00:02
#    --------- ----------------------------- 92.2/394.9 kB 291.5 kB/s eta 0:00:02
#    --------- ----------------------------- 92.2/394.9 kB 291.5 kB/s eta 0:00:02
#    ---------- --------------------------- 112.6/394.9 kB 297.7 kB/s eta 0:00:01
#    ------------- ------------------------ 143.4/394.9 kB 315.4 kB/s eta 0:00:01
#    -------------- ----------------------- 153.6/394.9 kB 305.7 kB/s eta 0:00:01
# ...

# %%
#import redis

# %%
#r= redis.Redis(host="localhost",port=25,db=0)

# %%
#r.hset("test",mapping={"name":"FesterBesterTester"})

# %%
#r.hgetall("test")

# %% [markdown]
# 10. Increment the count field of test and print it.

# %%
#r.hincrby
